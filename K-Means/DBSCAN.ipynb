# %% [markdown]
# # Problem with K-Means
# - Can fail sometimes on complex datasets

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles,make_moons

# %%
X,Y = make_moons(n_samples=200,noise=0.10)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=2)

# %%
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = km.cluster_centers_
label = km.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=label)
plt.scatter(centers[:,0],centers[:,1],color="red")
plt.show()

# %% [markdown]
# # DBSCAN
# - Density Based Spatial Clustering of Applications with Noise
# - Based upon the idea, that a cluster is a high density area surrounded by low density regions
# - Starts by exploring a small area, if density is "good enough" it considered the part of cluster and explores neighbours and so on, so it groups regions based upon density!

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbs = DBSCAN(eps=0.24,min_samples=3)

# %%
dbs.fit(X)
# Out:
# DBSCAN(algorithm='auto', eps=0.24, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=3, n_jobs=None, p=None)

# %%
Ypred = dbs.fit_predict(X)

# %%
plt.scatter(X[:,0],X[:,1],c=Ypred)
plt.show()

# %%
X,Y = make_circles(n_samples =500,noise=0.05,factor=0.5)

# %%
DBSCAN?

# %%
make_circles?
